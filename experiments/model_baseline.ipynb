# %% [markdown]
# 处理方式与Baseline一样，来对比去除缺失率高的特征值的前后差异，baseline的总特征维度为271348维，最终的AUC值为0.745905，

# %%
import numpy as np
import pandas as pd
import os
from scipy import sparse
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
import xgboost as xgb
import lightgbm as lgb
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./datasets/train_data.csv')
target = pd.read_csv('./datasets/train_target.csv', names=['label'], header=None)

data.drop(data.columns[[0]], axis=1, inplace=True)  #删除某列函数
target = target.reset_index(drop=True)

# %%
one_hot_feature=['LBS','age','carrier','consumptionAbility','education','gender','house','os','ct','marriageStatus','advertiserId','campaignId', 'creativeId',
           'adCategoryId', 'productId', 'productType']
vector_feature=['appIdAction','appIdInstall','interest1','interest2','interest3','interest4','interest5','kw1','kw2','kw3','topic1','topic2','topic3']
for feature in one_hot_feature:
    try:
        data[feature] = LabelEncoder().fit_transform(data[feature].apply(int))
    except:
        data[feature] = LabelEncoder().fit_transform(data[feature])

# %%
X_train_encoded = data[['creativeSize']]
X_test_encoded = data[['creativeSize']]
feature_index = {}
feature_index['creativeSize'] = '0-0'
length = 1
oc_encoder = OneHotEncoder()
for feature in one_hot_feature:
    oc_encoder.fit(data[feature].reshape(-1, 1))
    train_a=oc_encoder.transform(data[feature].values.reshape(-1, 1))
    buf = train_a.toarray().shape[1]
    feature_index[feature] = str(length)+'-'+str(length+buf-1)
    length += buf
    X_train_encoded = sparse.hstack((X_train_encoded, train_a))
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
ct_encoder = CountVectorizer()
for feature in vector_feature:
    ct_encoder.fit(data[feature])
    train_a = ct_encoder.transform(data[feature])
    buf = len(ct_encoder.vocabulary_)
    feature_index[feature] = str(length)+'-' + str(length+int(buf)-1)
    length += buf
    X_train_encoded = sparse.hstack((X_train_encoded, train_a))

# %%
for nam, val in feature_index.items():
    print(nam, val)
# Out:
# creativeSize 0-0
# LBS 1-636
# age 637-642
# carrier 643-646
# consumptionAbility 647-649
# education 650-657
# gender 658-660
# house 661-662
# os 663-667
# ct 668-732
# marriageStatus 733-754
# advertiserId 755-833
# campaignId 834-971
# creativeId 972-1144
# adCategoryId 1145-1184
# productId 1185-1217
# productType 1218-1221
# appIdAction 1222-6217
# appIdInstall 6218-59233
# interest1 59234-59346
# interest2 59347-59417
# interest3 59418-59418
# interest4 59419-59419
# interest5 59420-59546
# kw1 59547-208532
# kw2 208533-241312
# kw3 241313-247613
# topic1 247614-257594
# topic2 257595-267391
# topic3 267392-271347

# %%
y_train = np.array(target).squeeze()

# %%
clf = lgb.LGBMClassifier(
        boosting_type='gbdt', num_leaves=31, reg_alpha=0.0, reg_lambda=0.9,
        max_depth=-1, n_estimators=500, objective='binary',
        subsample=0.7, colsample_bytree=0.8, subsample_freq=1,
        learning_rate=0.05, min_child_weight=60, random_state=2018, n_jobs=-1
    )
clf.fit(X_train_encoded, y_train, eval_set=[(X_train_encoded, y_train)], eval_metric='auc',early_stopping_rounds=50)
# Out:
# [1]	valid_0's auc: 0.616389
# [464]	valid_0's auc: 0.743454
# [465]	valid_0's auc: 0.743506
# [466]	valid_0's auc: 0.743633
# [467]	valid_0's auc: 0.743656
# [468]	valid_0's auc: 0.743688
# [469]	valid_0's auc: 0.743756
# [470]	valid_0's auc: 0.74384
# [471]	valid_0's auc: 0.743915
# [472]	valid_0's auc: 0.744044
# [473]	valid_0's auc: 0.744103
# [474]	valid_0's auc: 0.74424
# [475]	valid_0's auc: 0.744299
# [476]	valid_0's auc: 0.744357
# [477]	valid_0's auc: 0.74445
# [478]	valid_0's auc: 0.744505
# [479]	valid_0's auc: 0.744523
# [480]	valid_0's auc: 0.744616
# [481]	valid_0's auc: 0.744648
# [482]	valid_0's auc: 0.744695
# [483]	valid_0's auc: 0.744789
# [484]	valid_0's auc: 0.744877
# [485]	valid_0's auc: 0.744958
# [486]	valid_0's auc: 0.745043
# [487]	valid_0's auc: 0.745131
# [488]	valid_0's auc: 0.745208
# [489]	valid_0's auc: 0.745288
# [490]	valid_0's auc: 0.745352
# [491]	valid_0's auc: 0.745395
# [492]	valid_0's auc: 0.745436
# [493]	valid_0's auc: 0.745501
# [494]	valid_0's auc: 0.745555
# [495]	valid_0's auc: 0.745612
# [496]	valid_0's auc: 0.745675
# [497]	valid_0's auc: 0.745715
# [498]	valid_0's auc: 0.745757
# [499]	valid_0's auc: 0.745842
# [500]	valid_0's auc: 0.745905
# Did not meet early stopping. Best iteration is:
# [500]	valid_0's auc: 0.745905
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=0.8,
#         learning_rate=0.05, max_depth=-1, min_child_samples=20,
#         min_child_weight=60, min_split_gain=0.0, n_estimators=500,
#         n_jobs=-1, num_leaves=31, objective='binary', random_state=2018,
#         reg_alpha=0.0, reg_lambda=0.9, silent=True, subsample=0.7,
#         subsample_for_bin=200000, subsample_freq=1)

# %%
fea_imp = clf.feature_importances_
top_index = np.argsort(fea_imp)
top_K = fea_imp[top_index[-50:]]
top_K
# Out:
# array([ 48,  48,  49,  49,  50,  50,  50,  51,  51,  51,  52,  59,  59,
#         60,  60,  60,  61,  61,  61,  61,  62,  62,  64,  65,  67,  67,
#         68,  69,  70,  70,  70,  71,  71,  72,  80,  81,  81,  83,  90,
#         90,  93, 101, 108, 109, 131, 135, 139, 145, 157, 658])

# %%
def print_fea_name(index, fea_imp):
    for i in index:
        for name, val in feature_index.items():
            lis = val.split('-')
            num1 = int(lis[0])
            num2 = int(lis[1])
            if(num1 <= i & i <= num2):
                print(name, val, 'dimention:', i, 'importance:',fea_imp[i])
                break

# %%
index = top_index[-100:].tolist()
index.reverse()
print_fea_name(index,fea_imp)
# Out:
# creativeSize 0-0 dimention: 0 importance: 658
# age 637-642 dimention: 639 importance: 157
# interest2 59347-59417 dimention: 59390 importance: 145
# productType 1218-1221 dimention: 1220 importance: 139
# interest2 59347-59417 dimention: 59347 importance: 135
# productType 1218-1221 dimention: 1221 importance: 131
# adCategoryId 1145-1184 dimention: 1161 importance: 109
# productType 1218-1221 dimention: 1218 importance: 108
# ct 668-732 dimention: 668 importance: 101
# interest2 59347-59417 dimention: 59406 importance: 93
# interest1 59234-59346 dimention: 59296 importance: 90
# interest2 59347-59417 dimention: 59359 importance: 90
# interest2 59347-59417 dimention: 59399 importance: 83
# advertiserId 755-833 dimention: 781 importance: 81
# marriageStatus 733-754 dimention: 735 importance: 81
# gender 658-660 dimention: 660 importance: 80
# LBS 1-636 dimention: 164 importance: 72
# interest2 59347-59417 dimention: 59367 importance: 71
# age 637-642 dimention: 642 importance: 71
# consumptionAbility 647-649 dimention: 649 importance: 70
# interest2 59347-59417 dimention: 59388 importance: 70
# interest1 59234-59346 dimention: 59323 importance: 70
# consumptionAbility 647-649 dimention: 647 importance: 69
# interest1 59234-59346 dimention: 59317 importance: 68
# carrier 643-646 dimention: 643 importance: 67
# age 637-642 dimention: 640 importance: 67
# kw2 208533-241312 dimention: 224537 importance: 65
# kw2 208533-241312 dimention: 234723 importance: 64
# interest5 59420-59546 dimention: 59530 importance: 62
# ct 668-732 dimention: 701 importance: 62
# interest2 59347-59417 dimention: 59409 importance: 61
# age 637-642 dimention: 638 importance: 61
# productId 1185-1217 dimention: 1188 importance: 61
# adCategoryId 1145-1184 dimention: 1151 importance: 61
# productId 1185-1217 dimention: 1185 importance: 60
# adCategoryId 1145-1184 dimention: 1153 importance: 60
# creativeId 972-1144 dimention: 974 importance: 60
# kw2 208533-241312 dimention: 217890 importance: 59
# adCategoryId 1145-1184 dimention: 1155 importance: 59
# adCategoryId 1145-1184 dimention: 1146 importance: 52
# consumptionAbility 647-649 dimention: 648 importance: 51
# advertiserId 755-833 dimention: 829 importance: 51
# campaignId 834-971 dimention: 870 importance: 51
# os 663-667 dimention: 664 importance: 50
# kw2 208533-241312 dimention: 236825 importance: 50
# interest5 59420-59546 dimention: 59484 importance: 50
# os 663-667 dimention: 666 importance: 49
# campaignId 834-971 dimention: 917 importance: 49
# interest2 59347-59417 dimention: 59371 importance: 48
# interest1 59234-59346 dimention: 59293 importance: 48
# kw2 208533-241312 dimention: 235451 importance: 48
# marriageStatus 733-754 dimention: 734 importance: 48
# kw2 208533-241312 dimention: 238361 importance: 47
# advertiserId 755-833 dimention: 805 importance: 46
# interest2 59347-59417 dimention: 59361 importance: 46
# interest5 59420-59546 dimention: 59499 importance: 45
# interest1 59234-59346 dimention: 59252 importance: 45
# gender 658-660 dimention: 659 importance: 45
# interest2 59347-59417 dimention: 59402 importance: 44
# advertiserId 755-833 dimention: 791 importance: 44
# age 637-642 dimention: 641 importance: 43
# interest2 59347-59417 dimention: 59414 importance: 43
# topic2 257595-267391 dimention: 258587 importance: 42
# education 650-657 dimention: 657 importance: 42
# kw2 208533-241312 dimention: 228274 importance: 42
# interest1 59234-59346 dimention: 59275 importance: 41
# interest5 59420-59546 dimention: 59462 importance: 41
# education 650-657 dimention: 652 importance: 39
# interest2 59347-59417 dimention: 59377 importance: 39
# interest1 59234-59346 dimention: 59306 importance: 38
# house 661-662 dimention: 661 importance: 38
# os 663-667 dimention: 663 importance: 38
# interest1 59234-59346 dimention: 59340 importance: 38
# adCategoryId 1145-1184 dimention: 1149 importance: 37
# creativeId 972-1144 dimention: 1124 importance: 37
# kw2 208533-241312 dimention: 221229 importance: 36
# marriageStatus 733-754 dimention: 740 importance: 36
# interest5 59420-59546 dimention: 59455 importance: 36
# advertiserId 755-833 dimention: 761 importance: 35
# topic2 257595-267391 dimention: 266319 importance: 35
# topic1 247614-257594 dimention: 257403 importance: 35
# interest5 59420-59546 dimention: 59453 importance: 35
# kw2 208533-241312 dimention: 235227 importance: 35
# kw2 208533-241312 dimention: 236951 importance: 35
# adCategoryId 1145-1184 dimention: 1163 importance: 35
# interest5 59420-59546 dimention: 59519 importance: 35
# interest5 59420-59546 dimention: 59497 importance: 34
# interest5 59420-59546 dimention: 59454 importance: 34
# interest5 59420-59546 dimention: 59430 importance: 34
# interest1 59234-59346 dimention: 59322 importance: 34
# interest1 59234-59346 dimention: 59244 importance: 33
# interest5 59420-59546 dimention: 59421 importance: 33
# kw2 208533-241312 dimention: 234675 importance: 32
# kw2 208533-241312 dimention: 218644 importance: 32
# interest5 59420-59546 dimention: 59506 importance: 31
# adCategoryId 1145-1184 dimention: 1150 importance: 31
# interest1 59234-59346 dimention: 59241 importance: 31
# interest5 59420-59546 dimention: 59489 importance: 31
# interest2 59347-59417 dimention: 59365 importance: 31
# advertiserId 755-833 dimention: 764 importance: 31

# %% [markdown]
# Baseline中特征重要度排序为：
# creativeSize age interest2 productType adCategoryId ct interest1 interest1 marriageStatus gender LBS consumptionAbility carrier kw2 interest5
# 并且特征kw1 apIdInstall appIdAction kw3 topic3的大部分importance为0 但是kw1、kw3、topic3有特例,考虑将min_df设为1000/879882

# %%
fea_imp.shape
# Out:
# (271348,)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879882 entries, 0 to 879881
# Data columns (total 32 columns):
# aid                   879882 non-null int64
# uid                   879882 non-null int64
# advertiserId          879882 non-null int64
# campaignId            879882 non-null int64
# creativeId            879882 non-null int64
# creativeSize          879882 non-null int64
# adCategoryId          879882 non-null int64
# productId             879882 non-null int64
# productType           879882 non-null int64
# LBS                   879882 non-null int64
# age                   879882 non-null int64
# appIdAction           879882 non-null object
# appIdInstall          879882 non-null object
# carrier               879882 non-null int64
# consumptionAbility    879882 non-null int64
# ct                    879882 non-null int64
# education             879882 non-null int64
# gender                879882 non-null int64
# house                 879882 non-null int64
# interest1             879882 non-null object
# interest2             879882 non-null object
# interest3             879882 non-null object
# interest4             879882 non-null object
# interest5             879882 non-null object
# kw1                   879882 non-null object
# kw2                   879882 non-null object
# kw3                   879882 non-null object
# marriageStatus        879882 non-null int64
# os                    879882 non-null int64
# topic1                879882 non-null object
# topic2                879882 non-null object
# topic3                879882 non-null object
# dtypes: int64(19), object(13)
# memory usage: 214.8+ MB
